# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from matplotlib import pyplot  as plt
import pandas as pd

# %%
data=pd.read_csv("/content/BRAIN TUMOR.csv")

# %%
data
# Out:
#     Unnamed: 0  X53416  M83670  X90908  ...  X54489  T55008  M10065.2       y
# 0            0      70     -81      25  ...     123       2        19   tumor
# 1            1     108     -30      -7  ...     271      -1       -51   tumor
# 2            2      75      -1       5  ...     127       7       192   tumor
# 3            3     871       4      14  ...      59       3       367   tumor
# 4            4     -92     -34      14  ...     265      -2       126   tumor
# 5            5      21     -13       5  ...       3       9       145   tumor
# 6            6     225     118      -5  ...     110       7       -14   tumor
# 7            7    -346     -35      37  ...      30      -5       -53   tumor
# 8            8    -378      31     -29  ...      97       0       -51   tumor
# 9            9     475     -79      20  ...      76      11        22   tumor
# 10          10     133      45     -11  ...      14       6        64   tumor
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Columns: 7466 entries, Unnamed: 0 to y
# dtypes: int64(7465), object(1)
# memory usage: 2.1+ MB

# %%
x=data.drop('y',axis=1)
y=data['y']

# %%
x
# Out:
#     Unnamed: 0  X53416  M83670  X90908  ...  M13699.1  X54489  T55008  M10065.2
# 0            0      70     -81      25  ...        -4     123       2        19
# 1            1     108     -30      -7  ...        -3     271      -1       -51
# 2            2      75      -1       5  ...       -14     127       7       192
# 3            3     871       4      14  ...        -4      59       3       367
# 4            4     -92     -34      14  ...         9     265      -2       126
# 5            5      21     -13       5  ...         4       3       9       145
# 6            6     225     118      -5  ...       -23     110       7       -14
# 7            7    -346     -35      37  ...        17      30      -5       -53
# 8            8    -378      31     -29  ...        15      97       0       -51
# 9            9     475     -79      20  ...        -4      76      11        22
# 10          10     133      45     -11  ...       -11      14       6        64
# ...

# %%
y=data['y']

# %%
data['y'].replace(['tumor','Normal'],[0, 1],inplace=True)
x=data.drop('y',axis=1)

# %%
x.isnull().value_counts()
# Out:
# Unnamed: 0  X53416  M83670  X90908  M97496  X90908.1  U37019  R48602  T96548  X64559  T55741  T64171  T54547  M95936  X54162  H57136  M10373  T55200  T46924  L11708  M18079  T46933  M98331  H54425  M76378  M26393  H59796  M82962  T55255  L13773  X53416.1  M63391  M63603  R33881  M95787  J03037  J02854  H37925  M83186  T72257  M84526  T76971  H77597  T67986  R99208  M22324  U03749  T63266  R93176  U14528  L02785  R94967  J03037.1  M74509  L11708.1  X77777  M16707  R69552  M76378.1  X63597  R50730  M76378.2  R87126  H43887  L08010  R28373  D00003  T92451  U17077  U25138  X86693  H57136.1  X73502  J03037.2  R70806  T51913  M64110  T50678  Z50753  H45474  M58286  U08854  M16451  X52679  X15882  D45370  T71025  M12272  M26683  D90313  U28249  L41351  M76424  L05144  T49192  H49325  L49169  X85785  H80342  M96839  X16356  T41265  R60877  H06524  R38279  M87770  T67077  T64297  T55731  M84526.1  J03930  M36634  X12496  L12760  Z18951  D00137  T53389  H23235  T60155  M96839.1  T61597  R87762
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.5,random_state=90)

# %%
from keras import utils as np_utils

# %%
n_classes=10

# %%
y.shape[0]
# Out:
# 36

# %%
model=Sequential()

# %%
model.add(Dense(64,activation='sigmoid',input_shape=(784,)))

# %%
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_16 (Dense)            (None, 64)                50240
#
#  dense_17 (Dense)            (None, 10)                650
#
# ...
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
model.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.2),metrics=['accuracy'])

# %%
history=[]

# %%
history=model.fit(x_train,y_train,epochs=10,batch_size=100,validation_split=0.3,verbose=1)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-255-c2bf752e2f02> in <module>()
# ----> 1 history=model.fit(x_train,y_train,epochs=10,batch_size=100,validation_split=0.3,verbose=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# ...
