# %% [markdown]
# DISTPLOT

# %%
import seaborn as s

# %% [markdown]
# LOADING DATA SET CALLED 'tips'

# %%
dataset=s.load_dataset('tips')

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# Uinsg distplot(univariate)

# %%
s.distplot(dataset['tip'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s.distplot(dataset['total_bill'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s.distplot(dataset['total_bill'],kde=False,bins=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s.distplot(dataset['total_bill'],kde=False,bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
s.jointplot(x='total_bill',y='tip',data=dataset,kind='scatter')

# %% [markdown]
# hex=density

# %%
s.jointplot(x='total_bill',y='tip',data=dataset,kind='hex')

# %% [markdown]
# reg=regression

# %%
s.jointplot(x='total_bill',y='tip',data=dataset,kind='reg')

# %%
s.jointplot(x='total_bill',y='tip',data=dataset,kind='resid')

# %% [markdown]
# PAIRPLOT

# %%
s.pairplot(dataset)

# %% [markdown]
# To identify the geneder type for each data point

# %%
s.pairplot(dataset,hue='sex',palette='coolwarm')

# %% [markdown]
# RUGPLOT

# %%
s.rugplot(dataset['tip'])

# %% [markdown]
# Also univariant, only creates a dashed line,
# KDE is implememented using RUGPLOT
# Very important
